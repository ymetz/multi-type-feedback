# %%
import pandas as pd
import wandb

# Initialize wandb
wandb.init(project="your_project_name")

# Fetch runs from your project
api = wandb.Api()
runs = api.runs("dynamic_rlhf_cheetah", filters={"display_name": {"$regex": "^DYNAMIC_RL_.*"}})
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ymetz to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Waiting for wandb.init()...
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/pfs/data6/home/kn/kn_kn/kn_pop257914/ws_feedback_querying/notebooks/wandb/run-20250714_103644-svalpnvj</code>
# Syncing run <strong><a href='https://wandb.ai/ymetz/your_project_name/runs/svalpnvj' target="_blank">gentle-silence-4</a></strong> to <a href='https://wandb.ai/ymetz/your_project_name' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ymetz/your_project_name' target="_blank">https://wandb.ai/ymetz/your_project_name</a>
# ...

# %%
runs[0].metadata["args"]
# Out:
# ['--algorithm',
#  'ppo',
#  '--environment',
#  'HalfCheetah-v5',
#  '--feedback-types',
#  'evaluative',
#  'comparative',
#  'demonstrative',
#  'corrective',
#  'descriptive',
#  'descriptive_preference',
#  '--reward-model-type',
#  'multi-head',
#  '--seed',
#  '12',
#  '--n-feedback-per-iteration',
#  '50',
#  '--reward-training-epochs',
#  '15',
#  '--feedback-buffer-size',
#  '5000',
#  '--reference-data-folder',
#  '../multi-type-feedback_iclr2025/rlhf/feedback',
#  '--expert-model-base-path',
#  'gt_agents',
#  '--wandb-project-name',
#  'dynamic_rlhf_cheetah']

# %%
# Create a list to store data from filtered runs
filtered_run_data = []

# Iterate through the runs
for run in runs:
    # Check if the run name starts with "ppo_"
    if run.name.startswith("DYNAMIC_RL_") and "noise" not in run.name and "ensemble" not in run.name:
        # Get the summary statistics (includes final values of metrics)
        summary = run.summary._json_dict

        # Get the history (includes all logged metrics)
        history = run.history(keys=["eval/mean_reward", "global_step"])
        #history = run.history(keys=["rollout/ep_rew_mean", "global_step"])

        # Combine summary and history data
        run_data = {
            "run_id": run.id,
            "run_name": run.name,
            **summary,
            **{f"{k}_history": v.tolist() for k, v in history.items()}
        }

        filtered_run_data.append(run_data)

# Create a DataFrame from filtered run data
orig_df = pd.DataFrame(filtered_run_data)

# %%
orig_df.columns
# Out:
# Index(['run_id', 'run_name', '_runtime', '_step', '_timestamp', '_wandb',
#        'epoch', 'eval/mean_ep_length', 'eval/mean_reward', 'global_step',
#        'initial_feedback/comparative_count',
#        'initial_feedback/corrective_count',
#        'initial_feedback/demonstrative_count',
#        'initial_feedback/descriptive_count',
#        'initial_feedback/descriptive_preference_count',
#        'initial_feedback/evaluative_count',
#        'initial_feedback/percent_complete', 'initial_feedback/total_collected',
#        'initial_reward_model/comparative_loss',
#        'initial_reward_model/corrective_loss',
#        'initial_reward_model/demonstrative_loss',
#        'initial_reward_model/descriptive_loss',
#        'initial_reward_model/descriptive_preference_loss',
#        'initial_reward_model/evaluative_loss', 'rollout/ep_len_mean',
#        'rollout/ep_rew_mean', 'time/fps', 'time/iterations',
#        'time/time_elapsed', 'time/total_timesteps', 'train/approx_kl',
# ...

# %%
from bisect import bisect_left
from collections import OrderedDict, defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import hex2color, rgb2hex
from scipy.ndimage import gaussian_filter1d


def generate_muted_colors(hex_color, num_colors=10, mute_factor=0.5):
    rgb = hex2color(hex_color)
    muted_colors = []
    for i in range(num_colors):
        muted_rgb = tuple(c + (1 - c) * mute_factor for c in rgb)
        muted_hex = rgb2hex(muted_rgb)
        muted_colors.append(muted_hex)
    return muted_colors

df = orig_df.copy()

score_field = "eval/mean_reward_history"

def extract_info(run_name):
    parts = run_name.split('_')
    # Expected format: DYNAMIC_RL_{algorithm}_{environment}_{reward_model_type}_{seed}
    # So parts[3] should be the environment and parts[4] should be the reward model type
    env = parts[3]
    reward_model_type = parts[4]
    print(reward_model_type)
    
    # Handle special case where reward_model_type is single_{feedback_type}
    if reward_model_type == "single":
        # The feedback type is in parts[5] (e.g., single_evaluative)
        feedback_type = parts[5]
        reward_model_type = f"single_{feedback_type}"
    
    return env, reward_model_type

# Function to interpolate NaN values in a series
def interpolate_nans(series):
    return pd.Series(series).interpolate().ffill().bfill().values

# Group runs by environment and reward model type
grouped_runs = defaultdict(lambda: defaultdict(list))
for _, row in df.iterrows():
    env, reward_model_type = extract_info(row['run_name'])
    # Convert string "nan" to np.nan and other values to float
    if isinstance(row[score_field], float):
        continue
    row[score_field] = [np.nan if x == "nan" else x for x in row[score_field]]
    # Interpolate NaN values in eval/mean_reward_history
    row[score_field] = interpolate_nans(row[score_field])
    grouped_runs[env][reward_model_type].append(row)

# Read the CSV file with evaluation scores
eval_df = pd.read_csv("../gt_agents/collected_results.csv")

# Define a color scale for reward model types
color_scale = OrderedDict([
    ('separate', '#1f77b4'),           # blue
    ('multi-head', '#ff7f0e'),         # orange
    ('unified', '#2ca02c'),            # green
    ('single_evaluative', '#d62728'),  # red
    ('single_comparative', '#9467bd'), # purple
    ('single_demonstrative', '#8c564b'), # brown
    ('single_corrective', '#e377c2'),  # pink
    ('single_descriptive', '#7f7f7f'), # gray
    ('single_preference', '#bcbd22'),  # olive
])

# Plotting function
def plot_environment(env, reward_model_runs):
    plt.figure(figsize=(15, 10))
    
    # Increase font size for all text elements
    plt.rcParams.update({'font.size': 18})  # Adjust this value as needed
    
    for reward_model_type in color_scale.keys():
        if reward_model_type not in reward_model_runs:
            continue  # Skip if this reward model type is not present for this environment
        
        runs = reward_model_runs[reward_model_type]
        color = color_scale.get(reward_model_type, '#7f7f7f')  # Default to gray if reward model type not in scale
        muted_colors = generate_muted_colors(color)
        
        # Find the maximum length of steps
        max_steps = max(len(run['global_step_history']) for run in runs)
        
        # Initialize arrays for rewards and steps
        all_rewards = np.full((len(runs), max_steps), np.nan)
        all_steps = np.full((len(runs), max_steps), np.nan)
        
        # Fill the arrays with available data
        for i, run in enumerate(runs):
            length = len(run['global_step_history'])
            length = bisect_left(run['global_step_history'], int(1e6))
            all_rewards[i, :length] = run[score_field][:length]
            all_steps[i, :length] = run['global_step_history'][:length]

        # Calculate statistics
        mean_reward = np.nanmean(all_rewards, axis=0)
        min_reward = mean_reward - np.nanstd(all_rewards, axis=0)
        max_reward = mean_reward + np.nanstd(all_rewards, axis=0)
        
        # Use the mean of steps for x-axis (ignoring NaNs)
        steps = np.nanmean(all_steps, axis=0)
        
        # Remove NaN entries
        valid = ~np.isnan(mean_reward)
        steps = steps[valid]
        mean_reward = mean_reward[valid]
        min_reward = min_reward[valid]
        max_reward = max_reward[valid]

        # Format display name for legend
        if reward_model_type.startswith('single_'):
            feedback_type = reward_model_type.replace('single_', '')
            if feedback_type == 'preference':
                display_name = "Single Descriptive Preferences"
            else:
                display_name = f"Single {feedback_type.capitalize()}"
        else:
            display_name = reward_model_type.replace('-', ' ').title()
        
        plt.plot(steps, mean_reward, label=f"{display_name}", color=color, linewidth=3.0)
        plt.fill_between(steps, min_reward, max_reward, alpha=0.2, color=color)

    # Filter eval scores for the current environment
    env_eval_scores = eval_df[eval_df['environment'] == env]
    
    # Sort and select the best four scores
    best_scores = env_eval_scores.nlargest(4, 'eval_score')
    
    # Calculate statistics for the best scores
    mean_score = best_scores['eval_score'].mean()
    min_score = best_scores['eval_score'].min()
    max_score = best_scores['eval_score'].max()
    
    # Plot evaluation scores as horizontal lines with updated styles
    plt.axhline(y=mean_score, color='grey', linewidth=3.5)
    plt.axhline(y=min_score, color='grey', linestyle='--', linewidth=2.5)
    plt.axhline(y=max_score, color='grey', linestyle='--', linewidth=2.5)
    
    plt.xlabel("Env. Steps", fontsize=18)
    plt.ylabel("Episode Rew.", fontsize=18)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"rl_reward_curves_{env}.png")
    plt.close()
    print(f"Reward plot for {env} environment has been saved to rl_reward_curves_{env}.png")

# Create plots for each environment
for env, reward_model_runs in grouped_runs.items():
    plot_environment(env, reward_model_runs)
# Out:
# multi-head
# multi-head
# multi-head
# multi-head
# multi-head
# separate
# separate
# separate
# unified
# separate
# separate
# unified
# unified
# unified
# multi-head
# multi-head
# multi-head
# multi-head
# unified
# unified
# unified
# multi-head
# unified
# unified
# unified
# separate
# separate
# separate
# separate
# separate
# separate
# separate
# separate
# separate
# separate
# multi-head
# multi-head
# multi-head
# unified
# unified
# unified
# unified
# unified
# single
# single
# single
# single
# single
# single
# single
# single
# single
# single
# single
# single
# single
# single
# single
# /scratch/slurm_tmpdir/job_664075/ipykernel_491795/4058364527.py:102: RuntimeWarning: Mean of empty slice
#   mean_reward = np.nanmean(all_rewards, axis=0)
# /opt/bwhpc/common/jupyter/base/2025-02-20/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:2019: RuntimeWarning: Degrees of freedom <= 0 for slice.
# ...
